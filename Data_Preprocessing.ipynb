# %% [markdown]
# <a href="https://colab.research.google.com/github/Ratchanontt/BSC_DPDM23/blob/main/Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Data

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Data_BSC_DPDM23')

# !pwd # เช็ค path ที่กำลังทำงานอยู่
# Out:
# /content/drive/MyDrive/Data_BSC_DPDM23

# %%
shopping_data = pd.read_csv("/content/drive/MyDrive/Data_BSC_DPDM23/customer_shopping_data.csv")

# %%
shopping_data
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 0        Credit Card     5/8/2022            Kanyon
# 1         Debit Card   12/12/2021    Forum Istanbul
# 2               Cash    9/11/2021         Metrocity
# 3        Credit Card   16/05/2021      Metropol AVM
# 4               Cash   24/10/2021            Kanyon
# ...              ...          ...               ...
# 99452    Credit Card   21/09/2022            Kanyon
# 99453           Cash   22/09/2021    Forum Istanbul
# 99454     Debit Card   28/03/2021         Metrocity
# 99455           Cash   16/03/2021      Istinye Park
# 99456    Credit Card   15/10/2022  Mall of Istanbul
#
# [99457 rows x 10 columns]

# %% [markdown]
# # ข้อมูลบางส่วนมีค่าตัวแปรบางตัวที่ไม่ทราบค่า (Missing Data)

# %% [markdown]
# ## Example

# %%
shopping_data.isnull().any()
# Out:
# invoice_no        False
# customer_id       False
# gender            False
# age               False
# category          False
# quantity          False
# price             False
# payment_method    False
# invoice_date      False
# shopping_mall     False
# dtype: bool

# %% [markdown]
# ### เราจะลบ Price ของ Record ที่เป็น Clothing, Cash, Metrocity เพื่อจำลอง Missing Value

# %% [markdown]
# #### ตรวจสอบค่า ก่อนการ missing

# %%
shop_miss = shopping_data[(shopping_data['category']== 'Clothing') &
 (shopping_data['payment_method']== 'Cash') &
  (shopping_data['shopping_mall']== 'Metrocity')]

# %%
shop_miss
# Out:
#       invoice_no customer_id  gender  age  category  quantity    price  \
# 2        I127801     C266599    Male   20  Clothing         1   300.08
# 382      I591015     C286181  Female   69  Clothing         1   300.08
# 446      I423124     C109593  Female   66  Clothing         1   300.08
# 531      I223795     C280596    Male   40  Clothing         3   900.24
# 647      I891465     C175833  Female   19  Clothing         1   300.08
# ...          ...         ...     ...  ...       ...       ...      ...
# 98987    I693615     C323954  Female   33  Clothing         2   600.16
# 99153    I922072     C336171    Male   47  Clothing         4  1200.32
# 99178    I135939     C211085    Male   40  Clothing         3   900.24
# 99339    I287566     C216529  Female   48  Clothing         1   300.08
# 99390    I283542     C780439    Male   35  Clothing         1   300.08
#
#       payment_method invoice_date shopping_mall
# 2               Cash    9/11/2021     Metrocity
# 382             Cash    12/9/2021     Metrocity
# 446             Cash     7/1/2023     Metrocity
# 531             Cash   26/12/2022     Metrocity
# 647             Cash   21/07/2022     Metrocity
# ...              ...          ...           ...
# 98987           Cash     7/2/2021     Metrocity
# 99153           Cash   22/01/2021     Metrocity
# 99178           Cash    1/11/2022     Metrocity
# 99339           Cash   25/02/2023     Metrocity
# 99390           Cash   25/04/2021     Metrocity
#
# [2284 rows x 10 columns]

# %%
shop_miss.describe()
# Out:
#                age     quantity        price
# count  2284.000000  2284.000000  2284.000000
# mean     43.657618     2.982049   894.853275
# std      14.974270     1.408979   422.806539
# min      18.000000     1.000000   300.080000
# 25%      30.750000     2.000000   600.160000
# 50%      44.000000     3.000000   900.240000
# 75%      57.000000     4.000000  1200.320000
# max      69.000000     5.000000  1500.400000

# %% [markdown]
# #### ทำให้ price missing

# %%
shop_miss['price'] = np.nan
# Out:
# <ipython-input-23-8ee4b50b52d8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shop_miss['price'] = np.nan

# %%
shop_miss
# Out:
#       invoice_no customer_id  gender  age  category  quantity  price  \
# 2        I127801     C266599    Male   20  Clothing         1    NaN
# 382      I591015     C286181  Female   69  Clothing         1    NaN
# 446      I423124     C109593  Female   66  Clothing         1    NaN
# 531      I223795     C280596    Male   40  Clothing         3    NaN
# 647      I891465     C175833  Female   19  Clothing         1    NaN
# ...          ...         ...     ...  ...       ...       ...    ...
# 98987    I693615     C323954  Female   33  Clothing         2    NaN
# 99153    I922072     C336171    Male   47  Clothing         4    NaN
# 99178    I135939     C211085    Male   40  Clothing         3    NaN
# 99339    I287566     C216529  Female   48  Clothing         1    NaN
# 99390    I283542     C780439    Male   35  Clothing         1    NaN
#
#       payment_method invoice_date shopping_mall
# 2               Cash    9/11/2021     Metrocity
# 382             Cash    12/9/2021     Metrocity
# 446             Cash     7/1/2023     Metrocity
# 531             Cash   26/12/2022     Metrocity
# 647             Cash   21/07/2022     Metrocity
# ...              ...          ...           ...
# 98987           Cash     7/2/2021     Metrocity
# 99153           Cash   22/01/2021     Metrocity
# 99178           Cash    1/11/2022     Metrocity
# 99339           Cash   25/02/2023     Metrocity
# 99390           Cash   25/04/2021     Metrocity
#
# [2284 rows x 10 columns]

# %% [markdown]
# #### แยก data ส่วนที่ไม่ missing ออกมา

# %%
# ต้องแยกออก เพราะ ถ้าไม่แยกก่อน ข้อมูลจะเยอะเกินไป อาจเกิดการซ้อนทับของข้อมูล
shop_nomiss = shopping_data[(shopping_data['category']!= 'Clothing') |
 (shopping_data['payment_method']!= 'Cash') |
  (shopping_data['shopping_mall']!= 'Metrocity')]

# %% [markdown]
# #### จับกลับมารวมกัน

# %%
new_shopping_data = pd.concat([shop_miss,shop_nomiss])
new_shopping_data.shape
# Out:
# (99457, 10)

# %% [markdown]
# ## Fix

# %%
new_shopping_data
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 2        I127801     C266599    Male   20         Clothing         1      NaN
# 382      I591015     C286181  Female   69         Clothing         1      NaN
# 446      I423124     C109593  Female   66         Clothing         1      NaN
# 531      I223795     C280596    Male   40         Clothing         3      NaN
# 647      I891465     C175833  Female   19         Clothing         1      NaN
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 2               Cash    9/11/2021         Metrocity
# 382             Cash    12/9/2021         Metrocity
# 446             Cash     7/1/2023         Metrocity
# 531             Cash   26/12/2022         Metrocity
# 647             Cash   21/07/2022         Metrocity
# ...              ...          ...               ...
# 99452    Credit Card   21/09/2022            Kanyon
# 99453           Cash   22/09/2021    Forum Istanbul
# 99454     Debit Card   28/03/2021         Metrocity
# 99455           Cash   16/03/2021      Istinye Park
# 99456    Credit Card   15/10/2022  Mall of Istanbul
#
# [99457 rows x 10 columns]

# %%
new_shopping_data.isnull().any()
# Out:
# invoice_no        False
# customer_id       False
# gender            False
# age               False
# category          False
# quantity          False
# price              True
# payment_method    False
# invoice_date      False
# shopping_mall     False
# dtype: bool

# %% [markdown]
# ### 1. Ignore Missing (ลบออกไปเลย)

# %% [markdown]
# #### Quiz
#
#
# *   Data หายไปกี่ %
# *   mean data รวมหลังจากแก้ missing เป็นเท่าไหร่

# %%
new_shopping_data_drop = new_shopping_data.dropna()

# %%
100*((len(new_shopping_data)-len(new_shopping_data_drop))/len(new_shopping_data))
# Out:
# 2.2964698311833254

# %%
new_shopping_data_drop.describe()
# Out:
#                 age      quantity         price
# count  97173.000000  97173.000000  97173.000000
# mean      43.421671      3.003931    684.423873
# std       14.990459      1.413123    949.438067
# min       18.000000      1.000000      5.230000
# 25%       30.000000      2.000000     40.660000
# 50%       43.000000      3.000000    203.300000
# 75%       56.000000      4.000000   1200.320000
# max       69.000000      5.000000   5250.000000

# %% [markdown]
# ### 2. เติมด้วย Unknown *เราจะเติมกับข้อมูล categorical

# %% [markdown]
# ### 3. เติมด้วย mean

# %% [markdown]
# #### Quiz
#
#
# *   mean ใหม่ เป็นเท่าไหร่?

# %%
mean_fill = new_shopping_data_drop['price'].mean()
mean_fill
# Out:
# 684.4238731952291

# %% [markdown]
# ### 4. เติมด้วยค่าเฉลี่ยของกลุ่ม

# %% [markdown]
# #### Quiz
#
#
# *   mean หลังเติมด้วยค่าเฉลี่ย Clothing
# *   mean หลังเติมด้วยค่าเฉลี่ย Cash
# *   mean หลังเติมด้วยค่าเฉลี่ย Metrocity
# *   mean หลังเติมด้วยค่าเฉลี่ย Cash + Metrocity

# %% [markdown]
# ##### mean หลังเติมด้วยค่าเฉลี่ย Clothing

# %%
na_clothing = new_shopping_data[new_shopping_data['category']=='Clothing']
na_clothing
# Out:
#       invoice_no customer_id  gender  age  category  quantity    price  \
# 2        I127801     C266599    Male   20  Clothing         1      NaN
# 382      I591015     C286181  Female   69  Clothing         1      NaN
# 446      I423124     C109593  Female   66  Clothing         1      NaN
# 531      I223795     C280596    Male   40  Clothing         3      NaN
# 647      I891465     C175833  Female   19  Clothing         1      NaN
# ...          ...         ...     ...  ...       ...       ...      ...
# 99435    I141871     C298790  Female   62  Clothing         3   900.24
# 99436    I579905     C265057  Female   57  Clothing         5  1500.40
# 99440    I887161     C137631  Female   58  Clothing         1   300.08
# 99442    I105959     C131810  Female   45  Clothing         4  1200.32
# 99449    I134399     C953724    Male   65  Clothing         1   300.08
#
#       payment_method invoice_date      shopping_mall
# 2               Cash    9/11/2021          Metrocity
# 382             Cash    12/9/2021          Metrocity
# 446             Cash     7/1/2023          Metrocity
# 531             Cash   26/12/2022          Metrocity
# 647             Cash   21/07/2022          Metrocity
# ...              ...          ...                ...
# 99435           Cash     2/2/2022  Emaar Square Mall
# 99436           Cash   27/03/2022        Cevahir AVM
# 99440           Cash   22/06/2021             Kanyon
# 99442     Debit Card     1/2/2021       Istinye Park
# 99449           Cash     1/1/2023             Kanyon
#
# [34487 rows x 10 columns]

# %%
na_clothing['price'].mean()
# Out:
# 901.5259373350307

# %%
fillna_clothing = new_shopping_data.fillna(na_clothing['price'].mean())
fillna_clothing
# Out:
#       invoice_no customer_id  gender  age         category  quantity  \
# 2        I127801     C266599    Male   20         Clothing         1
# 382      I591015     C286181  Female   69         Clothing         1
# 446      I423124     C109593  Female   66         Clothing         1
# 531      I223795     C280596    Male   40         Clothing         3
# 647      I891465     C175833  Female   19         Clothing         1
# ...          ...         ...     ...  ...              ...       ...
# 99452    I219422     C441542  Female   45         Souvenir         5
# 99453    I325143     C569580    Male   27  Food & Beverage         2
# 99454    I824010     C103292    Male   63  Food & Beverage         2
# 99455    I702964     C800631    Male   56       Technology         4
# 99456    I232867     C273973  Female   36         Souvenir         3
#
#              price payment_method invoice_date     shopping_mall
# 2       901.525937           Cash    9/11/2021         Metrocity
# 382     901.525937           Cash    12/9/2021         Metrocity
# 446     901.525937           Cash     7/1/2023         Metrocity
# 531     901.525937           Cash   26/12/2022         Metrocity
# 647     901.525937           Cash   21/07/2022         Metrocity
# ...            ...            ...          ...               ...
# 99452    58.650000    Credit Card   21/09/2022            Kanyon
# 99453    10.460000           Cash   22/09/2021    Forum Istanbul
# 99454    10.460000     Debit Card   28/03/2021         Metrocity
# 99455  4200.000000           Cash   16/03/2021      Istinye Park
# 99456    35.190000    Credit Card   15/10/2022  Mall of Istanbul
#
# [99457 rows x 10 columns]

# %%
fillna_clothing.describe()
# Out:
#                 age      quantity         price
# count  99457.000000  99457.000000  99457.000000
# mean      43.427089      3.003429    689.409557
# std       14.990054      1.413025    939.036135
# min       18.000000      1.000000      5.230000
# 25%       30.000000      2.000000     45.450000
# 50%       43.000000      3.000000    203.300000
# 75%       56.000000      4.000000   1200.320000
# max       69.000000      5.000000   5250.000000

# %%
fillna_clothing['price'].mean()
# Out:
# 689.4095566010759

# %% [markdown]
#  ##### mean หลังเติมด้วยค่าเฉลี่ย Cash

# %%
na_cash = new_shopping_data[new_shopping_data['payment_method']=='Cash']
na_cash
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 2        I127801     C266599    Male   20         Clothing         1      NaN
# 382      I591015     C286181  Female   69         Clothing         1      NaN
# 446      I423124     C109593  Female   66         Clothing         1      NaN
# 531      I223795     C280596    Male   40         Clothing         3      NaN
# 647      I891465     C175833  Female   19         Clothing         1      NaN
# ...          ...         ...     ...  ...              ...       ...      ...
# 99449    I134399     C953724    Male   65         Clothing         1   300.08
# 99450    I170504     C226974  Female   28            Books         1    15.15
# 99451    I675411     C513603    Male   50             Toys         5   179.20
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
#
#       payment_method invoice_date   shopping_mall
# 2               Cash    9/11/2021       Metrocity
# 382             Cash    12/9/2021       Metrocity
# 446             Cash     7/1/2023       Metrocity
# 531             Cash   26/12/2022       Metrocity
# 647             Cash   21/07/2022       Metrocity
# ...              ...          ...             ...
# 99449           Cash     1/1/2023          Kanyon
# 99450           Cash   28/02/2023    Zorlu Center
# 99451           Cash    9/10/2021    Metropol AVM
# 99453           Cash   22/09/2021  Forum Istanbul
# 99455           Cash   16/03/2021    Istinye Park
#
# [44447 rows x 10 columns]

# %%
na_cash['price'].mean()
# Out:
# 679.7710338448402

# %%
fillna_cash = new_shopping_data.fillna(na_cash['price'].mean())
fillna_cash
# Out:
#       invoice_no customer_id  gender  age         category  quantity  \
# 2        I127801     C266599    Male   20         Clothing         1
# 382      I591015     C286181  Female   69         Clothing         1
# 446      I423124     C109593  Female   66         Clothing         1
# 531      I223795     C280596    Male   40         Clothing         3
# 647      I891465     C175833  Female   19         Clothing         1
# ...          ...         ...     ...  ...              ...       ...
# 99452    I219422     C441542  Female   45         Souvenir         5
# 99453    I325143     C569580    Male   27  Food & Beverage         2
# 99454    I824010     C103292    Male   63  Food & Beverage         2
# 99455    I702964     C800631    Male   56       Technology         4
# 99456    I232867     C273973  Female   36         Souvenir         3
#
#              price payment_method invoice_date     shopping_mall
# 2       679.771034           Cash    9/11/2021         Metrocity
# 382     679.771034           Cash    12/9/2021         Metrocity
# 446     679.771034           Cash     7/1/2023         Metrocity
# 531     679.771034           Cash   26/12/2022         Metrocity
# 647     679.771034           Cash   21/07/2022         Metrocity
# ...            ...            ...          ...               ...
# 99452    58.650000    Credit Card   21/09/2022            Kanyon
# 99453    10.460000           Cash   22/09/2021    Forum Istanbul
# 99454    10.460000     Debit Card   28/03/2021         Metrocity
# 99455  4200.000000           Cash   16/03/2021      Istinye Park
# 99456    35.190000    Credit Card   15/10/2022  Mall of Istanbul
#
# [99457 rows x 10 columns]

# %%
fillna_cash.describe()
# Out:
#                 age      quantity         price
# count  99457.000000  99457.000000  99457.000000
# mean      43.427089      3.003429    684.317022
# std       14.990054      1.413025    938.473117
# min       18.000000      1.000000      5.230000
# 25%       30.000000      2.000000     45.450000
# 50%       43.000000      3.000000    203.300000
# 75%       56.000000      4.000000   1200.320000
# max       69.000000      5.000000   5250.000000

# %%
fillna_cash['price'].mean()
# Out:
# 684.317022143254

# %% [markdown]
# ##### mean หลังเติมด้วยค่าเฉลี่ย Metrocity

# %%
na_metro = new_shopping_data[new_shopping_data['shopping_mall']=='Metrocity']
na_metro
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 2        I127801     C266599    Male   20         Clothing         1      NaN
# 382      I591015     C286181  Female   69         Clothing         1      NaN
# 446      I423124     C109593  Female   66         Clothing         1      NaN
# 531      I223795     C280596    Male   40         Clothing         3      NaN
# 647      I891465     C175833  Female   19         Clothing         1      NaN
# ...          ...         ...     ...  ...              ...       ...      ...
# 99405    I651573     C425890    Male   56            Shoes         3  1800.51
# 99408    I949512     C217355  Female   47         Clothing         2   600.16
# 99424    I549710     C541824  Female   34       Technology         3  3150.00
# 99433    I403904     C142643    Male   28             Toys         1    35.84
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
#
#       payment_method invoice_date shopping_mall
# 2               Cash    9/11/2021     Metrocity
# 382             Cash    12/9/2021     Metrocity
# 446             Cash     7/1/2023     Metrocity
# 531             Cash   26/12/2022     Metrocity
# 647             Cash   21/07/2022     Metrocity
# ...              ...          ...           ...
# 99405     Debit Card     2/8/2022     Metrocity
# 99408    Credit Card   21/02/2021     Metrocity
# 99424           Cash   13/01/2021     Metrocity
# 99433    Credit Card    2/11/2022     Metrocity
# 99454     Debit Card   28/03/2021     Metrocity
#
# [15011 rows x 10 columns]

# %%
na_metro['price'].mean()
# Out:
# 644.7815816767502

# %%
fillna_metro = new_shopping_data.fillna(na_metro['price'].mean())
fillna_metro
# Out:
#       invoice_no customer_id  gender  age         category  quantity  \
# 2        I127801     C266599    Male   20         Clothing         1
# 382      I591015     C286181  Female   69         Clothing         1
# 446      I423124     C109593  Female   66         Clothing         1
# 531      I223795     C280596    Male   40         Clothing         3
# 647      I891465     C175833  Female   19         Clothing         1
# ...          ...         ...     ...  ...              ...       ...
# 99452    I219422     C441542  Female   45         Souvenir         5
# 99453    I325143     C569580    Male   27  Food & Beverage         2
# 99454    I824010     C103292    Male   63  Food & Beverage         2
# 99455    I702964     C800631    Male   56       Technology         4
# 99456    I232867     C273973  Female   36         Souvenir         3
#
#              price payment_method invoice_date     shopping_mall
# 2       644.781582           Cash    9/11/2021         Metrocity
# 382     644.781582           Cash    12/9/2021         Metrocity
# 446     644.781582           Cash     7/1/2023         Metrocity
# 531     644.781582           Cash   26/12/2022         Metrocity
# 647     644.781582           Cash   21/07/2022         Metrocity
# ...            ...            ...          ...               ...
# 99452    58.650000    Credit Card   21/09/2022            Kanyon
# 99453    10.460000           Cash   22/09/2021    Forum Istanbul
# 99454    10.460000     Debit Card   28/03/2021         Metrocity
# 99455  4200.000000           Cash   16/03/2021      Istinye Park
# 99456    35.190000    Credit Card   15/10/2022  Mall of Istanbul
#
# [99457 rows x 10 columns]

# %%
fillna_metro.describe()
# Out:
#                 age      quantity         price
# count  99457.000000  99457.000000  99457.000000
# mean      43.427089      3.003429    683.513500
# std       14.990054      1.413025    938.491645
# min       18.000000      1.000000      5.230000
# 25%       30.000000      2.000000     45.450000
# 50%       43.000000      3.000000    203.300000
# 75%       56.000000      4.000000   1200.320000
# max       69.000000      5.000000   5250.000000

# %%
fillna_metro['price'].mean()
# Out:
# 683.5134999301174

# %% [markdown]
# ##### mean หลังเติมด้วยค่าเฉลี่ย Cash + Metrocity

# %% [markdown]
# # ข้อมูลมีความซ้ำซ้อน (Duplicate Data)

# %% [markdown]
# ## Example

# %%
shop_dup = shopping_data[(shopping_data['category']== 'Clothing') &
 (shopping_data['payment_method']== 'Cash') &
  (shopping_data['shopping_mall']== 'Metrocity')]

# %%
shopping_dup = pd.concat([shopping_data,shop_dup])
shopping_dup
# Out:
#       invoice_no customer_id  gender  age  category  quantity    price  \
# 0        I138884     C241288  Female   28  Clothing         5  1500.40
# 1        I317333     C111565    Male   21     Shoes         3  1800.51
# 2        I127801     C266599    Male   20  Clothing         1   300.08
# 3        I173702     C988172  Female   66     Shoes         5  3000.85
# 4        I337046     C189076  Female   53     Books         4    60.60
# ...          ...         ...     ...  ...       ...       ...      ...
# 98987    I693615     C323954  Female   33  Clothing         2   600.16
# 99153    I922072     C336171    Male   47  Clothing         4  1200.32
# 99178    I135939     C211085    Male   40  Clothing         3   900.24
# 99339    I287566     C216529  Female   48  Clothing         1   300.08
# 99390    I283542     C780439    Male   35  Clothing         1   300.08
#
#       payment_method invoice_date   shopping_mall
# 0        Credit Card     5/8/2022          Kanyon
# 1         Debit Card   12/12/2021  Forum Istanbul
# 2               Cash    9/11/2021       Metrocity
# 3        Credit Card   16/05/2021    Metropol AVM
# 4               Cash   24/10/2021          Kanyon
# ...              ...          ...             ...
# 98987           Cash     7/2/2021       Metrocity
# 99153           Cash   22/01/2021       Metrocity
# 99178           Cash    1/11/2022       Metrocity
# 99339           Cash   25/02/2023       Metrocity
# 99390           Cash   25/04/2021       Metrocity
#
# [101741 rows x 10 columns]

# %%
new_shopping_dup = shopping_dup.sort_values(by='invoice_date') #เรียงตามวันที่
new_shopping_dup
# Out:
#       invoice_no customer_id  gender  age   category  quantity    price  \
# 41431    I880831     C362018    Male   47      Books         2    30.30
# 13715    I151379     C733582    Male   45   Clothing         1   300.08
# 36955    I966320     C169558  Female   59   Clothing         3   900.24
# 67503    I983410     C118410    Male   61       Toys         4   143.36
# 94539    I234686     C866358  Female   29  Cosmetics         2    81.32
# ...          ...         ...     ...  ...        ...       ...      ...
# 57595    I682579     C505081  Female   67  Cosmetics         4   162.64
# 48891    I208010     C261419  Female   23      Shoes         5  3000.85
# 95968    I328329     C294627    Male   21   Clothing         1   300.08
# 54569    I100441     C202089  Female   43  Cosmetics         3   121.98
# 94163    I172339     C298256  Female   33   Clothing         5  1500.40
#
#       payment_method invoice_date      shopping_mall
# 41431    Credit Card     1/1/2021  Emaar Square Mall
# 13715           Cash     1/1/2021       Metropol AVM
# 36955    Credit Card     1/1/2021   Mall of Istanbul
# 67503    Credit Card     1/1/2021        Cevahir AVM
# 94539     Debit Card     1/1/2021             Kanyon
# ...              ...          ...                ...
# 57595    Credit Card     9/9/2022          Metrocity
# 48891     Debit Card     9/9/2022             Kanyon
# 95968           Cash     9/9/2022       Metropol AVM
# 54569           Cash     9/9/2022       Istinye Park
# 94163           Cash     9/9/2022     Viaport Outlet
#
# [101741 rows x 10 columns]

# %%
new_shopping_dup.duplicated()
# Out:
# 41431    False
# 13715    False
# 36955    False
# 67503    False
# 94539    False
#          ...
# 57595    False
# 48891    False
# 95968    False
# 54569    False
# 94163    False
# Length: 101741, dtype: bool

# %%
new_shopping_dup[new_shopping_dup.duplicated()]
# Out:
#       invoice_no customer_id  gender  age  category  quantity    price  \
# 30645    I235671     C196703  Female   45  Clothing         2   600.16
# 27812    I836951     C382440    Male   54  Clothing         3   900.24
# 67018    I122424     C970402  Female   30  Clothing         1   300.08
# 52134    I740632     C283467  Female   49  Clothing         5  1500.40
# 32519    I341543     C754279  Female   53  Clothing         5  1500.40
# ...          ...         ...     ...  ...       ...       ...      ...
# 82563    I301995     C734886  Female   67  Clothing         2   600.16
# 63360    I180399     C286433  Female   31  Clothing         3   900.24
# 90298    I422962     C183016  Female   55  Clothing         2   600.16
# 97787    I275007     C259969    Male   61  Clothing         2   600.16
# 86164    I473988     C714996  Female   45  Clothing         4  1200.32
#
#       payment_method invoice_date shopping_mall
# 30645           Cash     1/1/2021     Metrocity
# 27812           Cash     1/1/2021     Metrocity
# 67018           Cash     1/1/2022     Metrocity
# 52134           Cash     1/1/2022     Metrocity
# 32519           Cash     1/1/2022     Metrocity
# ...              ...          ...           ...
# 82563           Cash     9/8/2022     Metrocity
# 63360           Cash     9/9/2021     Metrocity
# 90298           Cash     9/9/2021     Metrocity
# 97787           Cash     9/9/2022     Metrocity
# 86164           Cash     9/9/2022     Metrocity
#
# [2284 rows x 10 columns]

# %% [markdown]
# ## Fix

# %%
new_shopping_dup.drop_duplicates()
# Out:
#       invoice_no customer_id  gender  age   category  quantity    price  \
# 41431    I880831     C362018    Male   47      Books         2    30.30
# 13715    I151379     C733582    Male   45   Clothing         1   300.08
# 36955    I966320     C169558  Female   59   Clothing         3   900.24
# 67503    I983410     C118410    Male   61       Toys         4   143.36
# 94539    I234686     C866358  Female   29  Cosmetics         2    81.32
# ...          ...         ...     ...  ...        ...       ...      ...
# 57595    I682579     C505081  Female   67  Cosmetics         4   162.64
# 48891    I208010     C261419  Female   23      Shoes         5  3000.85
# 95968    I328329     C294627    Male   21   Clothing         1   300.08
# 54569    I100441     C202089  Female   43  Cosmetics         3   121.98
# 94163    I172339     C298256  Female   33   Clothing         5  1500.40
#
#       payment_method invoice_date      shopping_mall
# 41431    Credit Card     1/1/2021  Emaar Square Mall
# 13715           Cash     1/1/2021       Metropol AVM
# 36955    Credit Card     1/1/2021   Mall of Istanbul
# 67503    Credit Card     1/1/2021        Cevahir AVM
# 94539     Debit Card     1/1/2021             Kanyon
# ...              ...          ...                ...
# 57595    Credit Card     9/9/2022          Metrocity
# 48891     Debit Card     9/9/2022             Kanyon
# 95968           Cash     9/9/2022       Metropol AVM
# 54569           Cash     9/9/2022       Istinye Park
# 94163           Cash     9/9/2022     Viaport Outlet
#
# [99457 rows x 10 columns]

# %%
new_shopping_dup.drop_duplicates().duplicated().any()
# Out:
# False

# %% [markdown]
# # ข้อมูลบางตัวในชุดข้อมูลมีลักษณะผิดปกติหรือแตกต่างจากข้อมูลส่วนใหญ่ (Outlier)

# %% [markdown]
# ## Example

# %% [markdown]
# ## Fix

# %% [markdown]
# # ค่าตัวแปรบางตัวที่ไม่ถูกต้อง (Erroneous Data)

# %% [markdown]
# ## Example

# %% [markdown]
# ## Fix

# %% [markdown]
# # ข้อมูลมีค่าตัวแปรไม่สอดคล้องซึ่งกันและกัน (Inconsistent)

# %% [markdown]
# ## Example

# %% [markdown]
# ## Fix
