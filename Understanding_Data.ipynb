# %% [markdown]
# <a href="https://colab.research.google.com/github/Ratchanontt/BSC_DPDM23/blob/main/Understanding_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load Data

# %%
import pandas as pd

# %% [markdown]
# ## Mounting Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# เข้า path ที่เราสนใจใน google drive
import os
os.chdir('/content/drive/MyDrive/Data_BSC_DPDM23')

# !pwd # เช็ค path ที่กำลังทำงานอยู่

# %%
data_from_drive = pd.read_excel('/content/drive/MyDrive/Data_BSC_DPDM23/2563.xls', header = 2) # ชื่อ column อยู่ใน row ที่ 3

# %%
data_from_drive
# Out:
#     เลขที่คำขอ เลขที่บัตรส่งเสริม                        ชื่อบริษัทภาษาไทย  \
# 0       610707   62-0422-1-04-1-0  กรุงเทพ ไดอ์แคสซ์ติ้ง แอนด์ อินแจ๊กชั่น
# 1       620660   63-0107-1-00-1-0                        เจ้าพระยา คาร์บอน
# 2       610182   63-0101-1-00-1-0                        อาร์ต ออฟ เบคกิ้ง
# 3       620318   63-0080-1-00-0-0       เอ็นจีเค สปาร์คปลั๊กส์ (ประเทศไทย)
# 4       620185   63-0079-1-00-0-0       เอ็นจีเค สปาร์คปลั๊กส์ (ประเทศไทย)
# ..         ...                ...                                      ...
# 655    E630369   63-0669-1-00-0-0  อีเลคโทรลักซ์ โปรเฟสชั่นแนล (ประเทศไทย)
# 656    E630401   63-0682-1-00-1-0                            โกลว์ พลังงาน
# 657    E630277   63-0666-1-03-1-0         ยูนิค อุตสาหกรรมพลาสติก (แม่สอด)
# 658     610552   63-0676-1-00-1-0                   ไอชิน เอไอ (ประเทศไทย)
# 659    E630269   63-0668-1-00-1-0     เอ็มเอ็มซี อีเล็คโทรนิคส์ (ไทยแลนด์)
#
# ...

# %% [markdown]
# ## From Google sheet

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# %%
gsht = gc.open_by_key('1VESMkXY9lPwW7Vf7RrfxpRIMhq1nnfDW7bohBkNiJaM')

# %%
worksheet2 = gsht.worksheet('มิ.ย. 2563')
rows = worksheet2.get_all_values()
data_from_gsheets = pd.DataFrame.from_records(rows)

# %%
data_from_gsheets
# Out:
#             0                   1                                        2    \
# 0
# 1
# 2    เลขที่คำขอ  เลขที่บัตรส่งเสริม                        ชื่อบริษัทภาษาไทย
# 3        610707    62-0422-1-04-1-0  กรุงเทพ ไดอ์แคสซ์ติ้ง แอนด์ อินแจ๊กชั่น
# 4        620660    63-0107-1-00-1-0                        เจ้าพระยา คาร์บอน
# ..          ...                 ...                                      ...
# 658     E630369    63-0669-1-00-0-0  อีเลคโทรลักซ์ โปรเฟสชั่นแนล (ประเทศไทย)
# 659     E630401    63-0682-1-00-1-0                            โกลว์ พลังงาน
# 660     E630277    63-0666-1-03-1-0         ยูนิค อุตสาหกรรมพลาสติก (แม่สอด)
# 661      610552    63-0676-1-00-1-0                   ไอชิน เอไอ (ประเทศไทย)
# 662     E630269    63-0668-1-00-1-0     เอ็มเอ็มซี อีเล็คโทรนิคส์ (ไทยแลนด์)
#
#                                                    3              4    \
# 0
# 1
# 2                                    สถานที่ตั้งโรงงาน  เบอร์โทรศัพท์
# ...

# %%
# Set New header
# .columns เป็นการ set ชื่อ column จาก row ที่ 3
data_from_gsheets.columns = data_from_gsheets.iloc[2]

# %%
data_from_gsheets.columns
# Out:
# Index(['เลขที่คำขอ', 'เลขที่บัตรส่งเสริม', 'ชื่อบริษัทภาษาไทย',
#        'สถานที่ตั้งโรงงาน', 'เบอร์โทรศัพท์', 'เบอร์โทรสาร', 'จังหวัด',
#        'ประเภทกิจการ', 'ชื่อผลิตภัณฑ์', 'อุตสาหการ',
#        ...
#        'สาขาการตลาด', 'สาขาการจัดการ', 'สาขาเลขานุการ',
#        'สาขาคอมพิวเตอร์ธุรกิจ', 'สาขาการเงินการธนาคาร',
#        'สาขาพัฒนาชุมชน-การสหกรณ์', 'พาณิชยการ', 'สาขาอุตสาหกรรมการท่องเที่ยว',
#        'สาขาศิลปศาสตร์', 'อาชีวศึกษาบริหารธุรกิจ อื่นๆ'],
#       dtype='object', name=2, length=165)

# %%
# Skip rows
data_from_gsheets = data_from_gsheets.iloc[3:].reset_index().iloc[:,1:]
data_from_gsheets.head()
# Out:
# 2 เลขที่คำขอ เลขที่บัตรส่งเสริม                        ชื่อบริษัทภาษาไทย  \
# 0     610707   62-0422-1-04-1-0  กรุงเทพ ไดอ์แคสซ์ติ้ง แอนด์ อินแจ๊กชั่น
# 1     620660   63-0107-1-00-1-0                        เจ้าพระยา คาร์บอน
# 2     610182   63-0101-1-00-1-0                        อาร์ต ออฟ เบคกิ้ง
# 3     620318   63-0080-1-00-0-0       เอ็นจีเค สปาร์คปลั๊กส์ (ประเทศไทย)
# 4     620185   63-0079-1-00-0-0       เอ็นจีเค สปาร์คปลั๊กส์ (ประเทศไทย)
#
# 2                                  สถานที่ตั้งโรงงาน  เบอร์โทรศัพท์  \
# 0  46/1,46/2 หมู่ที่ 12 ถนนบางพลี-บางนาตราด ต.บาง...  02-3373078-84
# 1          ต.เขาล้าน อ.ทับสะแก ประจวบคีรีขันธ์ 77130    081-8412110
# 2  111/21 หมู่ที่ 2 ต.ท่าจีน อ.เมือง สมุทรสาคร 74000     034-440157
# 3   700/864 หมู่ที่ 1 ต.พานทอง อ.พานทอง ชลบุรี 20160
# 4   700/864 หมู่ที่ 1 ต.พานทอง อ.พานทอง ชลบุรี 20160
#
# 2    เบอร์โทรสาร          จังหวัด ประเภทกิจการ                  ชื่อผลิตภัณฑ์  \
# ...

# %%
data_from_gsheets.describe()
# Out:
# 2      เลขที่คำขอ เลขที่บัตรส่งเสริม           ชื่อบริษัทภาษาไทย  \
# count         660                660                         660
# unique        660                660                         558
# top        610707   62-0422-1-04-1-0  โซลาร์ เอนเนอร์ยี่ โซไซตี้
# freq            1                  1                          21
#
# 2                                  สถานที่ตั้งโรงงาน เบอร์โทรศัพท์  \
# count                                            660           660
# unique                                           603           388
# top     98/92-94 ถนนกะตะ ต.กะรน อ.เมือง ภูเก็ต 83100
# freq                                               8           223
#
# 2      เบอร์โทรสาร จังหวัด ประเภทกิจการ                         ชื่อผลิตภัณฑ์  \
# count          660     660          660                                   660
# unique          74      55          138                                   392
# top                 ชลบุรี    [7.1.1.2]  Electricity Power from Solar Rooftop
# ...

# %% [markdown]
# # Basic Statistics

# %% [markdown]
# # Vizualization

# %% [markdown]
# # Distance - Similarity

# %% [markdown]
# ## Z-score
